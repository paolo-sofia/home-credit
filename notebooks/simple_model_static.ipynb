# %%
import datetime

import pandas as pd
import polars as pl
import pathlib
import numpy as np
import lightgbm as lgb
import holidays
from dateutil.relativedelta import relativedelta 
import mlflow
import plotly.graph_objects as go

# %%
SEED = 666
mlflow.set_tracking_uri("/home/paolo/git/home-credit/data/mlflow_runs")

# %%
def get_learning_curves(model: lgb.LGBMModel, metric: str = "binary_logloss") -> go.Figure:
    keys = list(model.evals_result_.keys())
    train_key, valid_key = "", ""
    for key in keys:
        if "train" in key:
            train_key = key
        elif "valid" in key:
            valid_key = key
    
    results = pd.DataFrame({"train": model.evals_result_[train_key][metric], "valid": model.evals_result_[valid_key][metric]})

    fig = go.Figure()
    for col in results.columns:
        fig.add_trace(go.Scatter(x=results.index+1, y=results[col], mode='lines', name=f"{col}"))

    fig.update_layout(title='Learning curves',
                      xaxis_title='Iteration',
                      yaxis_title='Log Loss',
                      margin=dict(l=0,r=0,b=0,t=30),
                      )
    return fig

# %%
STATIC_0_PATH = pathlib.Path("/home/paolo/git/home-credit/data/raw/parquet_files/train/train_static_0_0.parquet")
STATIC_1_PATH = pathlib.Path("/home/paolo/git/home-credit/data/raw/parquet_files/train/train_static_0_1.parquet")
BASE_PATH = pathlib.Path("/home/paolo/git/home-credit/data/raw/parquet_files/train/train_base.parquet")

# %%
HOLIDAYS = list(holidays.country_holidays("US", years=range(2000, 2024)).keys())

# %%
train_base: pl.LazyFrame = pl.scan_parquet(BASE_PATH).with_columns(pl.col("date_decision").cast(pl.Date))
static_0: pl.LazyFrame = pl.scan_parquet(STATIC_0_PATH)
static_1: pl.LazyFrame = pl.scan_parquet(STATIC_1_PATH)
data: pl.LazyFrame = pl.concat([static_0, static_1]).lazy()

# %%
train_base = train_base.with_columns(
    pl.col("date_decision").dt.year().alias("year"),
    (2 * np.pi * pl.col("date_decision").dt.month() / 12).sin().cast(pl.Float32).alias("sin(month)"),
    (2 * np.pi * pl.col("date_decision").dt.month() / 12).cos().cast(pl.Float32).alias("cos(month)"),
    pl.when(pl.col("date_decision").dt.is_leap_year())
    .then(np.pi * pl.col("date_decision").dt.day() / 366)
    .otherwise(np.pi * pl.col("date_decision").dt.day() / 365)
    .sin()
    .cast(pl.Float32)
    .alias("sin(day_of_year)"),
    pl.when(pl.col("date_decision").dt.is_leap_year())
    .then(np.pi * pl.col("date_decision").dt.day() / 366)
    .otherwise(np.pi * pl.col("date_decision").dt.day() / 365)
    .cos()
    .cast(pl.Float32)
    .alias("cos(day_of_year)"),
    # pl.col("datetime").dt.quarter().alias("quarter"),
    pl.col("date_decision")
    .dt.strftime("%Y-%m-%d")
    .is_in([x.strftime("%Y-%m-%d") for x in HOLIDAYS])
    .alias("is_holiday"),
    (2 * np.pi * pl.col("WEEK_NUM") / 52).sin().cast(pl.Float32).alias("sin(WEEK_NUM)"),
    (2 * np.pi * pl.col("WEEK_NUM") / 52).cos().cast(pl.Float32).alias("cos(WEEK_NUM)")
).drop(["WEEK_NUM", "MONTH"])

# %%
data = data.drop([col for col in data.columns if "birth" in col])

# %%
transforms = []
for col, dtype in zip(data.columns, data.dtypes):
    if col.endswith("D"):
        transforms.append(
            pl.when(pl.col(col).is_null()).then(pl.lit(False)).otherwise(pl.lit(True)).cast(pl.Boolean).alias(col)
        )
    elif dtype == pl.String and not col.endswith("D"):
        transforms.append(
            pl.col(col).fill_null("UNKNOWN").cast(pl.Categorical)
        )
    elif dtype in [pl.Float64, pl.Float32]:
        transforms.append(
            pl.col(col).fill_null(pl.col(col).median()).cast(pl.Float32)
        )
    elif col in {"opencred_647L"}:
        transforms.append(
            pl.col(col).fill_null(pl.col(col).median()).shrink_dtype()
        )
    elif col in {"isdebitcard_729L", "isbidproductrequest_292L", "equalitydataagreement_891L", "equalityempfrom_62L"}:
        transforms.append(
            pl.col(col).fill_null(pl.lit(False)).shrink_dtype()
        )

data = data.with_columns(*transforms)

# %%
data = train_base.join(other=data, on=["case_id"], how="inner").drop("case_id")

# %%
def split_train_validation(dataframe: pl.LazyFrame, test_months: float = 0.2) -> tuple[pl.LazyFrame, pl.LazyFrame]:
    min_date: datetime.date = dataframe.select("date_decision").min().collect().item(0,0)
    max_date: datetime.date = dataframe.select("date_decision").max().collect().item(0,0)
    total_months: int = (max_date - min_date).days // 30 + 1
    
    test_months: int = round(total_months * test_months)
    
    start_test_date: datetime.date = max_date - relativedelta(months=test_months)
    return dataframe.filter(pl.col("date_decision") < start_test_date).drop("date_decision"), dataframe.filter(pl.col("date_decision") >= start_test_date).drop("date_decision")


train, valid = split_train_validation(data)
y_train, y_valid = train.select("target").collect().to_series().to_pandas(), valid.select("target").collect().to_series().to_pandas()
x_train, x_valid = train.drop("target"), valid.drop("target")

# %%
def convert_object_to_categorical(data: pd.DataFrame) -> pd.DataFrame:
    for col in data.columns:
        if data[col].dtype == "object":
            data[col] = data[col].astype("category")
    
    return data

x_train = convert_object_to_categorical(x_train.collect().to_pandas())
x_valid = convert_object_to_categorical(x_valid.collect().to_pandas())

# %%
mlflow.set_experiment("simple_model_static")

eval_results = {}

mlflow.lightgbm.autolog(
    log_input_examples=False, 
    log_model_signatures=True, 
    log_models=True, 
    log_datasets=False, 
    disable=False, 
    exclusive=False, 
    disable_for_unsupported_versions=False, 
    silent=False, 
    registered_model_name=None, 
    extra_tags=None    
)

with mlflow.start_run():
    model = lgb.LGBMClassifier(
        random_state=SEED,
        n_jobs=-1,
        boosting_type='gbdt', 
        num_leaves=31, 
        max_depth=-1, 
        learning_rate=0.1, 
        n_estimators=10_000, 
        subsample_for_bin=200_000, 
        objective="binary", 
        class_weight="balanced", 
        min_split_gain=0.0, 
        min_child_weight=0.001, 
        min_child_samples=20, 
        subsample=0.5, 
        subsample_freq=0, 
        colsample_bytree=0.5, 
        reg_alpha=0.0, 
        reg_lambda=0.0, 
        importance_type='split'
    )
    
    model.fit(
        X=x_train,
        y=y_train,
        eval_set=[(x_train, y_train), (x_valid, y_valid)],
        eval_metric=["binary_logloss", "auc"],
        callbacks=[
            lgb.log_evaluation(),
            lgb.record_evaluation(eval_results),
            lgb.early_stopping(stopping_rounds=100, first_metric_only=True),
        ],
    )

    fig = get_learning_curves(model)
    mlflow.log_figure(fig, artifact_file="consumer_model.png")
# Out:
# [LightGBM] [Info] Number of positive: 43866, number of negative: 1292863
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.172335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 19086
# [LightGBM] [Info] Number of data points in the train set: 1336729, number of used features: 166
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [1]	training's binary_logloss: 0.679905	training's auc: 0.711383	valid_1's binary_logloss: 0.680316	valid_1's auc: 0.741526
# Training until validation scores don't improve for 100 rounds
# [2]	training's binary_logloss: 0.667766	training's auc: 0.733749	valid_1's binary_logloss: 0.668078	valid_1's auc: 0.761123
# [3]	training's binary_logloss: 0.658037	training's auc: 0.739202	valid_1's binary_logloss: 0.659632	valid_1's auc: 0.767298
# [4]	training's binary_logloss: 0.649268	training's auc: 0.742273	valid_1's binary_logloss: 0.652862	valid_1's auc: 0.764982
# [5]	training's binary_logloss: 0.642192	training's auc: 0.744485	valid_1's binary_logloss: 0.647358	valid_1's auc: 0.767416
# [6]	training's binary_logloss: 0.63564	training's auc: 0.746389	valid_1's binary_logloss: 0.64119	valid_1's auc: 0.768986
# [7]	training's binary_logloss: 0.630023	training's auc: 0.748166	valid_1's binary_logloss: 0.636073	valid_1's auc: 0.771621
# [8]	training's binary_logloss: 0.624757	training's auc: 0.749997	valid_1's binary_logloss: 0.631094	valid_1's auc: 0.77472
# [9]	training's binary_logloss: 0.619977	training's auc: 0.752208	valid_1's binary_logloss: 0.627319	valid_1's auc: 0.776983
# [10]	training's binary_logloss: 0.615179	training's auc: 0.754547	valid_1's binary_logloss: 0.622241	valid_1's auc: 0.779596
# [11]	training's binary_logloss: 0.611008	training's auc: 0.757065	valid_1's binary_logloss: 0.619061	valid_1's auc: 0.781004
# [12]	training's binary_logloss: 0.607399	training's auc: 0.758947	valid_1's binary_logloss: 0.615395	valid_1's auc: 0.782431
# [13]	training's binary_logloss: 0.603853	training's auc: 0.761378	valid_1's binary_logloss: 0.612642	valid_1's auc: 0.78423
# [14]	training's binary_logloss: 0.600858	training's auc: 0.762491	valid_1's binary_logloss: 0.610281	valid_1's auc: 0.784802
# [15]	training's binary_logloss: 0.598051	training's auc: 0.76386	valid_1's binary_logloss: 0.608212	valid_1's auc: 0.785831
# [16]	training's binary_logloss: 0.595733	training's auc: 0.764615	valid_1's binary_logloss: 0.605365	valid_1's auc: 0.786533
# [17]	training's binary_logloss: 0.593339	training's auc: 0.766366	valid_1's binary_logloss: 0.602177	valid_1's auc: 0.786494
# [18]	training's binary_logloss: 0.591111	training's auc: 0.767475	valid_1's binary_logloss: 0.5985	valid_1's auc: 0.787274
# [19]	training's binary_logloss: 0.588862	training's auc: 0.768764	valid_1's binary_logloss: 0.595733	valid_1's auc: 0.788294
# [20]	training's binary_logloss: 0.586804	training's auc: 0.770495	valid_1's binary_logloss: 0.594762	valid_1's auc: 0.788992
# [21]	training's binary_logloss: 0.584523	training's auc: 0.772096	valid_1's binary_logloss: 0.593406	valid_1's auc: 0.790243
# [22]	training's binary_logloss: 0.582578	training's auc: 0.773579	valid_1's binary_logloss: 0.592039	valid_1's auc: 0.790831
# [23]	training's binary_logloss: 0.58081	training's auc: 0.774992	valid_1's binary_logloss: 0.590586	valid_1's auc: 0.791582
# [24]	training's binary_logloss: 0.579124	training's auc: 0.775951	valid_1's binary_logloss: 0.588276	valid_1's auc: 0.792485
# [25]	training's binary_logloss: 0.57733	training's auc: 0.777439	valid_1's binary_logloss: 0.585061	valid_1's auc: 0.793184
# [26]	training's binary_logloss: 0.575798	training's auc: 0.778855	valid_1's binary_logloss: 0.581728	valid_1's auc: 0.793837
# [27]	training's binary_logloss: 0.57451	training's auc: 0.779624	valid_1's binary_logloss: 0.583288	valid_1's auc: 0.79391
# [28]	training's binary_logloss: 0.573066	training's auc: 0.780719	valid_1's binary_logloss: 0.580251	valid_1's auc: 0.794125
# [29]	training's binary_logloss: 0.571613	training's auc: 0.781797	valid_1's binary_logloss: 0.578297	valid_1's auc: 0.79448
# [30]	training's binary_logloss: 0.570287	training's auc: 0.782728	valid_1's binary_logloss: 0.576182	valid_1's auc: 0.795083
# [31]	training's binary_logloss: 0.568851	training's auc: 0.78372	valid_1's binary_logloss: 0.5747	valid_1's auc: 0.795741
# [32]	training's binary_logloss: 0.567827	training's auc: 0.784371	valid_1's binary_logloss: 0.571524	valid_1's auc: 0.796376
# [33]	training's binary_logloss: 0.566748	training's auc: 0.785169	valid_1's binary_logloss: 0.567772	valid_1's auc: 0.796432
# [34]	training's binary_logloss: 0.565529	training's auc: 0.786026	valid_1's binary_logloss: 0.565853	valid_1's auc: 0.796309
# [35]	training's binary_logloss: 0.564544	training's auc: 0.786517	valid_1's binary_logloss: 0.564796	valid_1's auc: 0.797152
# [36]	training's binary_logloss: 0.563655	training's auc: 0.78696	valid_1's binary_logloss: 0.564975	valid_1's auc: 0.797693
# [37]	training's binary_logloss: 0.562691	training's auc: 0.787791	valid_1's binary_logloss: 0.563692	valid_1's auc: 0.79775
# [38]	training's binary_logloss: 0.561858	training's auc: 0.788249	valid_1's binary_logloss: 0.562427	valid_1's auc: 0.798142
# [39]	training's binary_logloss: 0.560936	training's auc: 0.788836	valid_1's binary_logloss: 0.562393	valid_1's auc: 0.799101
# [40]	training's binary_logloss: 0.559979	training's auc: 0.789682	valid_1's binary_logloss: 0.562105	valid_1's auc: 0.799251
# [41]	training's binary_logloss: 0.558974	training's auc: 0.79061	valid_1's binary_logloss: 0.560235	valid_1's auc: 0.799502
# [42]	training's binary_logloss: 0.558286	training's auc: 0.791079	valid_1's binary_logloss: 0.558302	valid_1's auc: 0.799959
# [43]	training's binary_logloss: 0.557464	training's auc: 0.791764	valid_1's binary_logloss: 0.554052	valid_1's auc: 0.799777
# [44]	training's binary_logloss: 0.556778	training's auc: 0.792139	valid_1's binary_logloss: 0.553392	valid_1's auc: 0.800223
# [45]	training's binary_logloss: 0.556077	training's auc: 0.792651	valid_1's binary_logloss: 0.552351	valid_1's auc: 0.800709
# [46]	training's binary_logloss: 0.555455	training's auc: 0.792997	valid_1's binary_logloss: 0.550529	valid_1's auc: 0.800956
# [241]	training's binary_logloss: 0.495482	training's auc: 0.843675	valid_1's binary_logloss: 0.459667	valid_1's auc: 0.805977
# [242]	training's binary_logloss: 0.495297	training's auc: 0.843785	valid_1's binary_logloss: 0.459514	valid_1's auc: 0.806016
# [243]	training's binary_logloss: 0.495138	training's auc: 0.843935	valid_1's binary_logloss: 0.459291	valid_1's auc: 0.805932
# [244]	training's binary_logloss: 0.4949	training's auc: 0.844143	valid_1's binary_logloss: 0.459097	valid_1's auc: 0.805846
# [245]	training's binary_logloss: 0.49476	training's auc: 0.844251	valid_1's binary_logloss: 0.459105	valid_1's auc: 0.805837
# [246]	training's binary_logloss: 0.494576	training's auc: 0.844371	valid_1's binary_logloss: 0.459179	valid_1's auc: 0.805928
# [247]	training's binary_logloss: 0.49442	training's auc: 0.844505	valid_1's binary_logloss: 0.459237	valid_1's auc: 0.805871
# [248]	training's binary_logloss: 0.494232	training's auc: 0.844661	valid_1's binary_logloss: 0.459013	valid_1's auc: 0.805882
# [249]	training's binary_logloss: 0.494028	training's auc: 0.844859	valid_1's binary_logloss: 0.458974	valid_1's auc: 0.805834
# [250]	training's binary_logloss: 0.493767	training's auc: 0.845089	valid_1's binary_logloss: 0.456874	valid_1's auc: 0.805518
# [251]	training's binary_logloss: 0.493607	training's auc: 0.845243	valid_1's binary_logloss: 0.456705	valid_1's auc: 0.805474
# [252]	training's binary_logloss: 0.493461	training's auc: 0.845378	valid_1's binary_logloss: 0.456512	valid_1's auc: 0.805417
# [253]	training's binary_logloss: 0.493305	training's auc: 0.845508	valid_1's binary_logloss: 0.456321	valid_1's auc: 0.805326
# [254]	training's binary_logloss: 0.49311	training's auc: 0.845666	valid_1's binary_logloss: 0.456186	valid_1's auc: 0.805322
# [255]	training's binary_logloss: 0.492928	training's auc: 0.845856	valid_1's binary_logloss: 0.456087	valid_1's auc: 0.805266
# [256]	training's binary_logloss: 0.492774	training's auc: 0.845988	valid_1's binary_logloss: 0.455924	valid_1's auc: 0.80531
# [257]	training's binary_logloss: 0.492642	training's auc: 0.846105	valid_1's binary_logloss: 0.455938	valid_1's auc: 0.805292
# [258]	training's binary_logloss: 0.492494	training's auc: 0.846233	valid_1's binary_logloss: 0.45571	valid_1's auc: 0.805235
# [259]	training's binary_logloss: 0.492312	training's auc: 0.846396	valid_1's binary_logloss: 0.455656	valid_1's auc: 0.805225
# [260]	training's binary_logloss: 0.49219	training's auc: 0.846495	valid_1's binary_logloss: 0.454989	valid_1's auc: 0.804694
# [261]	training's binary_logloss: 0.49206	training's auc: 0.846613	valid_1's binary_logloss: 0.454799	valid_1's auc: 0.804647
# [262]	training's binary_logloss: 0.491907	training's auc: 0.846736	valid_1's binary_logloss: 0.45464	valid_1's auc: 0.804602
# [263]	training's binary_logloss: 0.491803	training's auc: 0.846819	valid_1's binary_logloss: 0.454551	valid_1's auc: 0.804584
# [264]	training's binary_logloss: 0.491636	training's auc: 0.846973	valid_1's binary_logloss: 0.454463	valid_1's auc: 0.804479
# [265]	training's binary_logloss: 0.491512	training's auc: 0.84709	valid_1's binary_logloss: 0.454389	valid_1's auc: 0.804477
# [266]	training's binary_logloss: 0.491338	training's auc: 0.84725	valid_1's binary_logloss: 0.45424	valid_1's auc: 0.804481
# [267]	training's binary_logloss: 0.491214	training's auc: 0.847358	valid_1's binary_logloss: 0.454384	valid_1's auc: 0.80445
# [268]	training's binary_logloss: 0.491049	training's auc: 0.847493	valid_1's binary_logloss: 0.453837	valid_1's auc: 0.804407
# [269]	training's binary_logloss: 0.490879	training's auc: 0.847642	valid_1's binary_logloss: 0.453709	valid_1's auc: 0.804361
# [270]	training's binary_logloss: 0.490737	training's auc: 0.847761	valid_1's binary_logloss: 0.453484	valid_1's auc: 0.80435
# [271]	training's binary_logloss: 0.490436	training's auc: 0.847988	valid_1's binary_logloss: 0.453447	valid_1's auc: 0.804255
# [272]	training's binary_logloss: 0.49024	training's auc: 0.848159	valid_1's binary_logloss: 0.453174	valid_1's auc: 0.804217
# [273]	training's binary_logloss: 0.490091	training's auc: 0.8483	valid_1's binary_logloss: 0.453038	valid_1's auc: 0.804069
# [274]	training's binary_logloss: 0.489917	training's auc: 0.848464	valid_1's binary_logloss: 0.453095	valid_1's auc: 0.804071
# [275]	training's binary_logloss: 0.489731	training's auc: 0.848636	valid_1's binary_logloss: 0.452932	valid_1's auc: 0.804048
# [276]	training's binary_logloss: 0.489614	training's auc: 0.848718	valid_1's binary_logloss: 0.452897	valid_1's auc: 0.80407
# [277]	training's binary_logloss: 0.48944	training's auc: 0.848856	valid_1's binary_logloss: 0.452718	valid_1's auc: 0.804062
# [278]	training's binary_logloss: 0.489229	training's auc: 0.849021	valid_1's binary_logloss: 0.452633	valid_1's auc: 0.804022
# [279]	training's binary_logloss: 0.48911	training's auc: 0.849132	valid_1's binary_logloss: 0.452464	valid_1's auc: 0.80401
# [280]	training's binary_logloss: 0.488967	training's auc: 0.849251	valid_1's binary_logloss: 0.452325	valid_1's auc: 0.804052
# [281]	training's binary_logloss: 0.488751	training's auc: 0.849434	valid_1's binary_logloss: 0.452164	valid_1's auc: 0.804045
# [282]	training's binary_logloss: 0.488639	training's auc: 0.849517	valid_1's binary_logloss: 0.451991	valid_1's auc: 0.803957
# [283]	training's binary_logloss: 0.488486	training's auc: 0.849619	valid_1's binary_logloss: 0.451956	valid_1's auc: 0.804025
# [284]	training's binary_logloss: 0.488334	training's auc: 0.84976	valid_1's binary_logloss: 0.451832	valid_1's auc: 0.803972
# [285]	training's binary_logloss: 0.488157	training's auc: 0.849897	valid_1's binary_logloss: 0.451619	valid_1's auc: 0.803894
# [286]	training's binary_logloss: 0.487996	training's auc: 0.85003	valid_1's binary_logloss: 0.451427	valid_1's auc: 0.803784
# [287]	training's binary_logloss: 0.487726	training's auc: 0.85026	valid_1's binary_logloss: 0.451297	valid_1's auc: 0.803753
# [288]	training's binary_logloss: 0.487615	training's auc: 0.850342	valid_1's binary_logloss: 0.451092	valid_1's auc: 0.80366
# [289]	training's binary_logloss: 0.487445	training's auc: 0.850498	valid_1's binary_logloss: 0.45101	valid_1's auc: 0.803679
# [290]	training's binary_logloss: 0.487319	training's auc: 0.850597	valid_1's binary_logloss: 0.450968	valid_1's auc: 0.803686
# [291]	training's binary_logloss: 0.487203	training's auc: 0.850695	valid_1's binary_logloss: 0.4507	valid_1's auc: 0.803678
# [292]	training's binary_logloss: 0.487059	training's auc: 0.850812	valid_1's binary_logloss: 0.45051	valid_1's auc: 0.80361
# [293]	training's binary_logloss: 0.486838	training's auc: 0.850994	valid_1's binary_logloss: 0.45042	valid_1's auc: 0.803614
# [294]	training's binary_logloss: 0.48671	training's auc: 0.851115	valid_1's binary_logloss: 0.450233	valid_1's auc: 0.803613
# [295]	training's binary_logloss: 0.486547	training's auc: 0.85126	valid_1's binary_logloss: 0.450082	valid_1's auc: 0.803609
# [296]	training's binary_logloss: 0.486421	training's auc: 0.851353	valid_1's binary_logloss: 0.449955	valid_1's auc: 0.803598
# [297]	training's binary_logloss: 0.486339	training's auc: 0.85142	valid_1's binary_logloss: 0.449853	valid_1's auc: 0.803553
# [298]	training's binary_logloss: 0.48614	training's auc: 0.851602	valid_1's binary_logloss: 0.44975	valid_1's auc: 0.803577
# [299]	training's binary_logloss: 0.485982	training's auc: 0.851718	valid_1's binary_logloss: 0.44976	valid_1's auc: 0.80356
# [300]	training's binary_logloss: 0.485817	training's auc: 0.851875	valid_1's binary_logloss: 0.449716	valid_1's auc: 0.80354
# [301]	training's binary_logloss: 0.485607	training's auc: 0.852019	valid_1's binary_logloss: 0.449569	valid_1's auc: 0.803532
# [302]	training's binary_logloss: 0.485447	training's auc: 0.852154	valid_1's binary_logloss: 0.449563	valid_1's auc: 0.803509
# [303]	training's binary_logloss: 0.485331	training's auc: 0.852259	valid_1's binary_logloss: 0.449391	valid_1's auc: 0.803528
# [304]	training's binary_logloss: 0.485201	training's auc: 0.852366	valid_1's binary_logloss: 0.449275	valid_1's auc: 0.803487
# [305]	training's binary_logloss: 0.485079	training's auc: 0.852473	valid_1's binary_logloss: 0.449116	valid_1's auc: 0.803474
# [306]	training's binary_logloss: 0.484947	training's auc: 0.852575	valid_1's binary_logloss: 0.448969	valid_1's auc: 0.8034
# [307]	training's binary_logloss: 0.484823	training's auc: 0.852683	valid_1's binary_logloss: 0.448716	valid_1's auc: 0.803383
# [308]	training's binary_logloss: 0.484723	training's auc: 0.852774	valid_1's binary_logloss: 0.44865	valid_1's auc: 0.803386
# [309]	training's binary_logloss: 0.484564	training's auc: 0.852919	valid_1's binary_logloss: 0.448407	valid_1's auc: 0.803418
# [310]	training's binary_logloss: 0.484369	training's auc: 0.853061	valid_1's binary_logloss: 0.448457	valid_1's auc: 0.803422
# [311]	training's binary_logloss: 0.484297	training's auc: 0.853115	valid_1's binary_logloss: 0.448365	valid_1's auc: 0.803298
# [312]	training's binary_logloss: 0.484071	training's auc: 0.853272	valid_1's binary_logloss: 0.448241	valid_1's auc: 0.803433
# [313]	training's binary_logloss: 0.483852	training's auc: 0.853449	valid_1's binary_logloss: 0.448054	valid_1's auc: 0.803458
# [314]	training's binary_logloss: 0.483704	training's auc: 0.853574	valid_1's binary_logloss: 0.446537	valid_1's auc: 0.803456
# [315]	training's binary_logloss: 0.483553	training's auc: 0.85366	valid_1's binary_logloss: 0.446404	valid_1's auc: 0.803467
# [316]	training's binary_logloss: 0.48343	training's auc: 0.853767	valid_1's binary_logloss: 0.445881	valid_1's auc: 0.802825
# [317]	training's binary_logloss: 0.483336	training's auc: 0.853846	valid_1's binary_logloss: 0.445777	valid_1's auc: 0.802788
# [318]	training's binary_logloss: 0.483257	training's auc: 0.85391	valid_1's binary_logloss: 0.445715	valid_1's auc: 0.802772
# [319]	training's binary_logloss: 0.483075	training's auc: 0.854085	valid_1's binary_logloss: 0.445513	valid_1's auc: 0.80274
# [320]	training's binary_logloss: 0.482985	training's auc: 0.854177	valid_1's binary_logloss: 0.445487	valid_1's auc: 0.802741
# [321]	training's binary_logloss: 0.482801	training's auc: 0.854331	valid_1's binary_logloss: 0.445372	valid_1's auc: 0.802719
# [322]	training's binary_logloss: 0.482689	training's auc: 0.854427	valid_1's binary_logloss: 0.445283	valid_1's auc: 0.802689
# [323]	training's binary_logloss: 0.482585	training's auc: 0.854475	valid_1's binary_logloss: 0.445214	valid_1's auc: 0.802676
# [324]	training's binary_logloss: 0.482445	training's auc: 0.854593	valid_1's binary_logloss: 0.444985	valid_1's auc: 0.802653
# [325]	training's binary_logloss: 0.482288	training's auc: 0.854725	valid_1's binary_logloss: 0.444768	valid_1's auc: 0.802559
# [326]	training's binary_logloss: 0.482121	training's auc: 0.854832	valid_1's binary_logloss: 0.444757	valid_1's auc: 0.802532
# [327]	training's binary_logloss: 0.481966	training's auc: 0.854973	valid_1's binary_logloss: 0.4447	valid_1's auc: 0.802519
# [328]	training's binary_logloss: 0.48179	training's auc: 0.855153	valid_1's binary_logloss: 0.444424	valid_1's auc: 0.802533
# [329]	training's binary_logloss: 0.481692	training's auc: 0.855245	valid_1's binary_logloss: 0.444435	valid_1's auc: 0.802533
# [330]	training's binary_logloss: 0.481493	training's auc: 0.855418	valid_1's binary_logloss: 0.444324	valid_1's auc: 0.802516
# [331]	training's binary_logloss: 0.481397	training's auc: 0.855502	valid_1's binary_logloss: 0.444232	valid_1's auc: 0.802408
# [332]	training's binary_logloss: 0.481297	training's auc: 0.855584	valid_1's binary_logloss: 0.444138	valid_1's auc: 0.802436
# [333]	training's binary_logloss: 0.481224	training's auc: 0.855642	valid_1's binary_logloss: 0.444097	valid_1's auc: 0.802427
# [334]	training's binary_logloss: 0.48114	training's auc: 0.855723	valid_1's binary_logloss: 0.44404	valid_1's auc: 0.802422
# [335]	training's binary_logloss: 0.480982	training's auc: 0.855873	valid_1's binary_logloss: 0.443833	valid_1's auc: 0.802359
# [336]	training's binary_logloss: 0.48083	training's auc: 0.856002	valid_1's binary_logloss: 0.443556	valid_1's auc: 0.802341
# [337]	training's binary_logloss: 0.480634	training's auc: 0.856158	valid_1's binary_logloss: 0.443085	valid_1's auc: 0.802214
# [338]	training's binary_logloss: 0.480465	training's auc: 0.856303	valid_1's binary_logloss: 0.442892	valid_1's auc: 0.802188
# [339]	training's binary_logloss: 0.480343	training's auc: 0.85641	valid_1's binary_logloss: 0.441969	valid_1's auc: 0.802008
# [340]	training's binary_logloss: 0.480235	training's auc: 0.856496	valid_1's binary_logloss: 0.442061	valid_1's auc: 0.80201
# [341]	training's binary_logloss: 0.480007	training's auc: 0.856694	valid_1's binary_logloss: 0.441933	valid_1's auc: 0.801892
# [342]	training's binary_logloss: 0.479845	training's auc: 0.856802	valid_1's binary_logloss: 0.44199	valid_1's auc: 0.801875
# [343]	training's binary_logloss: 0.479699	training's auc: 0.856934	valid_1's binary_logloss: 0.441874	valid_1's auc: 0.80178
# [344]	training's binary_logloss: 0.479523	training's auc: 0.857093	valid_1's binary_logloss: 0.441742	valid_1's auc: 0.801797
# [345]	training's binary_logloss: 0.47927	training's auc: 0.857317	valid_1's binary_logloss: 0.441582	valid_1's auc: 0.801795
# [346]	training's binary_logloss: 0.479157	training's auc: 0.857434	valid_1's binary_logloss: 0.441307	valid_1's auc: 0.801807
# [347]	training's binary_logloss: 0.479071	training's auc: 0.8575	valid_1's binary_logloss: 0.441147	valid_1's auc: 0.801582
# [348]	training's binary_logloss: 0.478898	training's auc: 0.857645	valid_1's binary_logloss: 0.441028	valid_1's auc: 0.801503
# [349]	training's binary_logloss: 0.478809	training's auc: 0.85772	valid_1's binary_logloss: 0.440907	valid_1's auc: 0.801502
# [350]	training's binary_logloss: 0.478647	training's auc: 0.857842	valid_1's binary_logloss: 0.440825	valid_1's auc: 0.801488
# [351]	training's binary_logloss: 0.478383	training's auc: 0.858035	valid_1's binary_logloss: 0.440631	valid_1's auc: 0.80154
# [352]	training's binary_logloss: 0.478292	training's auc: 0.858117	valid_1's binary_logloss: 0.44054	valid_1's auc: 0.801432
# [353]	training's binary_logloss: 0.478204	training's auc: 0.858184	valid_1's binary_logloss: 0.440449	valid_1's auc: 0.801429
# [354]	training's binary_logloss: 0.478071	training's auc: 0.858285	valid_1's binary_logloss: 0.440428	valid_1's auc: 0.801452
# [355]	training's binary_logloss: 0.477976	training's auc: 0.858366	valid_1's binary_logloss: 0.440377	valid_1's auc: 0.801432
# [356]	training's binary_logloss: 0.4778	training's auc: 0.858503	valid_1's binary_logloss: 0.440182	valid_1's auc: 0.801424
# [357]	training's binary_logloss: 0.477712	training's auc: 0.85858	valid_1's binary_logloss: 0.440111	valid_1's auc: 0.801411
# [358]	training's binary_logloss: 0.477557	training's auc: 0.85869	valid_1's binary_logloss: 0.439995	valid_1's auc: 0.801443
# [359]	training's binary_logloss: 0.47746	training's auc: 0.858772	valid_1's binary_logloss: 0.440024	valid_1's auc: 0.801443
# [360]	training's binary_logloss: 0.47735	training's auc: 0.858875	valid_1's binary_logloss: 0.439996	valid_1's auc: 0.801402
# [361]	training's binary_logloss: 0.477195	training's auc: 0.859005	valid_1's binary_logloss: 0.439713	valid_1's auc: 0.801317
# [362]	training's binary_logloss: 0.477038	training's auc: 0.85915	valid_1's binary_logloss: 0.439516	valid_1's auc: 0.801347
# [363]	training's binary_logloss: 0.476882	training's auc: 0.859291	valid_1's binary_logloss: 0.439483	valid_1's auc: 0.80132
# [364]	training's binary_logloss: 0.476755	training's auc: 0.859393	valid_1's binary_logloss: 0.439269	valid_1's auc: 0.801314
# [365]	training's binary_logloss: 0.47664	training's auc: 0.859492	valid_1's binary_logloss: 0.439067	valid_1's auc: 0.801282
# [366]	training's binary_logloss: 0.476527	training's auc: 0.859599	valid_1's binary_logloss: 0.438753	valid_1's auc: 0.801158
# [367]	training's binary_logloss: 0.476428	training's auc: 0.859687	valid_1's binary_logloss: 0.438608	valid_1's auc: 0.801227
# [368]	training's binary_logloss: 0.476307	training's auc: 0.859784	valid_1's binary_logloss: 0.438482	valid_1's auc: 0.801214
# [369]	training's binary_logloss: 0.476196	training's auc: 0.859895	valid_1's binary_logloss: 0.438411	valid_1's auc: 0.801133
# [370]	training's binary_logloss: 0.47604	training's auc: 0.860049	valid_1's binary_logloss: 0.438226	valid_1's auc: 0.800993
# [371]	training's binary_logloss: 0.475859	training's auc: 0.860179	valid_1's binary_logloss: 0.43802	valid_1's auc: 0.801
# [372]	training's binary_logloss: 0.475698	training's auc: 0.860322	valid_1's binary_logloss: 0.438097	valid_1's auc: 0.801
# [373]	training's binary_logloss: 0.475563	training's auc: 0.860448	valid_1's binary_logloss: 0.438007	valid_1's auc: 0.800974
# [374]	training's binary_logloss: 0.475402	training's auc: 0.860554	valid_1's binary_logloss: 0.437592	valid_1's auc: 0.800862
# [375]	training's binary_logloss: 0.475261	training's auc: 0.860677	valid_1's binary_logloss: 0.43749	valid_1's auc: 0.800795
# [376]	training's binary_logloss: 0.475168	training's auc: 0.860761	valid_1's binary_logloss: 0.437451	valid_1's auc: 0.800788
# [377]	training's binary_logloss: 0.475029	training's auc: 0.860873	valid_1's binary_logloss: 0.437327	valid_1's auc: 0.800671
# [378]	training's binary_logloss: 0.474908	training's auc: 0.860977	valid_1's binary_logloss: 0.437239	valid_1's auc: 0.800655
# ...
# [2225]	training's binary_logloss: 0.332321	training's auc: 0.951233	valid_1's binary_logloss: 0.265054	valid_1's auc: 0.737393
# [2226]	training's binary_logloss: 0.332248	training's auc: 0.95126	valid_1's binary_logloss: 0.265027	valid_1's auc: 0.737422
# [2227]	training's binary_logloss: 0.332232	training's auc: 0.951264	valid_1's binary_logloss: 0.264568	valid_1's auc: 0.736156
# [2228]	training's binary_logloss: 0.332175	training's auc: 0.95129	valid_1's binary_logloss: 0.264544	valid_1's auc: 0.736148
# [2229]	training's binary_logloss: 0.332094	training's auc: 0.951328	valid_1's binary_logloss: 0.264506	valid_1's auc: 0.736114
# [2230]	training's binary_logloss: 0.332043	training's auc: 0.951345	valid_1's binary_logloss: 0.264499	valid_1's auc: 0.736152
# [2231]	training's binary_logloss: 0.331986	training's auc: 0.951379	valid_1's binary_logloss: 0.26448	valid_1's auc: 0.736141
# [2232]	training's binary_logloss: 0.331942	training's auc: 0.951397	valid_1's binary_logloss: 0.264455	valid_1's auc: 0.736143
# [2233]	training's binary_logloss: 0.331914	training's auc: 0.951409	valid_1's binary_logloss: 0.264442	valid_1's auc: 0.736151
# [2234]	training's binary_logloss: 0.331838	training's auc: 0.951447	valid_1's binary_logloss: 0.264393	valid_1's auc: 0.736159
# [2235]	training's binary_logloss: 0.331809	training's auc: 0.951459	valid_1's binary_logloss: 0.264377	valid_1's auc: 0.736159
# [2236]	training's binary_logloss: 0.331748	training's auc: 0.951488	valid_1's binary_logloss: 0.264362	valid_1's auc: 0.736112
# [2237]	training's binary_logloss: 0.331687	training's auc: 0.951513	valid_1's binary_logloss: 0.264387	valid_1's auc: 0.736111
# [2238]	training's binary_logloss: 0.331646	training's auc: 0.951531	valid_1's binary_logloss: 0.264366	valid_1's auc: 0.736126
# [2239]	training's binary_logloss: 0.331585	training's auc: 0.951559	valid_1's binary_logloss: 0.264323	valid_1's auc: 0.736135
# [2240]	training's binary_logloss: 0.331526	training's auc: 0.95158	valid_1's binary_logloss: 0.264288	valid_1's auc: 0.736133
# [2241]	training's binary_logloss: 0.331484	training's auc: 0.951598	valid_1's binary_logloss: 0.264231	valid_1's auc: 0.736164
# [2242]	training's binary_logloss: 0.331453	training's auc: 0.951614	valid_1's binary_logloss: 0.26421	valid_1's auc: 0.736156
# [2243]	training's binary_logloss: 0.331437	training's auc: 0.951617	valid_1's binary_logloss: 0.264207	valid_1's auc: 0.73615
# [2244]	training's binary_logloss: 0.331383	training's auc: 0.951643	valid_1's binary_logloss: 0.264202	valid_1's auc: 0.736137
# [2245]	training's binary_logloss: 0.331329	training's auc: 0.951666	valid_1's binary_logloss: 0.264206	valid_1's auc: 0.73615
# [2246]	training's binary_logloss: 0.331282	training's auc: 0.951687	valid_1's binary_logloss: 0.264192	valid_1's auc: 0.736148
# [2247]	training's binary_logloss: 0.331206	training's auc: 0.951733	valid_1's binary_logloss: 0.264126	valid_1's auc: 0.736159
# [2248]	training's binary_logloss: 0.331144	training's auc: 0.951762	valid_1's binary_logloss: 0.264096	valid_1's auc: 0.736152
# [2249]	training's binary_logloss: 0.331104	training's auc: 0.95178	valid_1's binary_logloss: 0.264105	valid_1's auc: 0.736102
# [2250]	training's binary_logloss: 0.331037	training's auc: 0.951806	valid_1's binary_logloss: 0.264043	valid_1's auc: 0.736077
# [2251]	training's binary_logloss: 0.331021	training's auc: 0.95181	valid_1's binary_logloss: 0.264034	valid_1's auc: 0.736016
# [2252]	training's binary_logloss: 0.33098	training's auc: 0.951827	valid_1's binary_logloss: 0.264006	valid_1's auc: 0.736006
# [2253]	training's binary_logloss: 0.330938	training's auc: 0.951843	valid_1's binary_logloss: 0.263978	valid_1's auc: 0.736008
# [2254]	training's binary_logloss: 0.330893	training's auc: 0.951858	valid_1's binary_logloss: 0.26392	valid_1's auc: 0.736023
# [2255]	training's binary_logloss: 0.330818	training's auc: 0.951904	valid_1's binary_logloss: 0.263878	valid_1's auc: 0.736008
# [2256]	training's binary_logloss: 0.330774	training's auc: 0.951918	valid_1's binary_logloss: 0.263854	valid_1's auc: 0.73597
# [2257]	training's binary_logloss: 0.330708	training's auc: 0.951947	valid_1's binary_logloss: 0.263769	valid_1's auc: 0.735993
# [2258]	training's binary_logloss: 0.330657	training's auc: 0.951969	valid_1's binary_logloss: 0.263745	valid_1's auc: 0.73599
# [2259]	training's binary_logloss: 0.330603	training's auc: 0.951993	valid_1's binary_logloss: 0.263735	valid_1's auc: 0.735957
# [2260]	training's binary_logloss: 0.330552	training's auc: 0.952012	valid_1's binary_logloss: 0.263695	valid_1's auc: 0.735943
# [2261]	training's binary_logloss: 0.330487	training's auc: 0.952044	valid_1's binary_logloss: 0.263711	valid_1's auc: 0.735947
# [2262]	training's binary_logloss: 0.330432	training's auc: 0.952068	valid_1's binary_logloss: 0.263667	valid_1's auc: 0.735906
# [2263]	training's binary_logloss: 0.330373	training's auc: 0.952093	valid_1's binary_logloss: 0.263604	valid_1's auc: 0.735888
# [2264]	training's binary_logloss: 0.330339	training's auc: 0.952113	valid_1's binary_logloss: 0.263582	valid_1's auc: 0.735861
# [2265]	training's binary_logloss: 0.330315	training's auc: 0.95212	valid_1's binary_logloss: 0.263557	valid_1's auc: 0.735524
# [2266]	training's binary_logloss: 0.330292	training's auc: 0.952126	valid_1's binary_logloss: 0.263547	valid_1's auc: 0.735459
# [2267]	training's binary_logloss: 0.330256	training's auc: 0.952137	valid_1's binary_logloss: 0.263523	valid_1's auc: 0.73544
# [2268]	training's binary_logloss: 0.330198	training's auc: 0.952161	valid_1's binary_logloss: 0.26346	valid_1's auc: 0.735339
# [2269]	training's binary_logloss: 0.330144	training's auc: 0.952186	valid_1's binary_logloss: 0.263435	valid_1's auc: 0.735337
# [2270]	training's binary_logloss: 0.330054	training's auc: 0.952232	valid_1's binary_logloss: 0.263346	valid_1's auc: 0.735353
# [2271]	training's binary_logloss: 0.329977	training's auc: 0.952268	valid_1's binary_logloss: 0.263301	valid_1's auc: 0.73535
# [2272]	training's binary_logloss: 0.329924	training's auc: 0.952295	valid_1's binary_logloss: 0.263297	valid_1's auc: 0.735326
# [2273]	training's binary_logloss: 0.329866	training's auc: 0.952323	valid_1's binary_logloss: 0.263291	valid_1's auc: 0.735305
# [2274]	training's binary_logloss: 0.32981	training's auc: 0.952361	valid_1's binary_logloss: 0.263276	valid_1's auc: 0.735304
# [2275]	training's binary_logloss: 0.329763	training's auc: 0.952382	valid_1's binary_logloss: 0.263041	valid_1's auc: 0.735272
# [2276]	training's binary_logloss: 0.329696	training's auc: 0.952421	valid_1's binary_logloss: 0.262991	valid_1's auc: 0.735271
# [2277]	training's binary_logloss: 0.329631	training's auc: 0.952451	valid_1's binary_logloss: 0.262945	valid_1's auc: 0.735241
# [2278]	training's binary_logloss: 0.329572	training's auc: 0.952475	valid_1's binary_logloss: 0.262889	valid_1's auc: 0.735209
# [2279]	training's binary_logloss: 0.329512	training's auc: 0.952498	valid_1's binary_logloss: 0.262852	valid_1's auc: 0.735188
# [2280]	training's binary_logloss: 0.329473	training's auc: 0.952512	valid_1's binary_logloss: 0.262811	valid_1's auc: 0.735179
# [2281]	training's binary_logloss: 0.329447	training's auc: 0.952519	valid_1's binary_logloss: 0.262802	valid_1's auc: 0.735164
# [2282]	training's binary_logloss: 0.329391	training's auc: 0.952544	valid_1's binary_logloss: 0.262808	valid_1's auc: 0.735161
# [2283]	training's binary_logloss: 0.329339	training's auc: 0.952563	valid_1's binary_logloss: 0.262762	valid_1's auc: 0.735077
# [2284]	training's binary_logloss: 0.329302	training's auc: 0.952574	valid_1's binary_logloss: 0.262714	valid_1's auc: 0.735112
# [2285]	training's binary_logloss: 0.329287	training's auc: 0.952577	valid_1's binary_logloss: 0.262712	valid_1's auc: 0.735107
# [2286]	training's binary_logloss: 0.329234	training's auc: 0.952605	valid_1's binary_logloss: 0.262726	valid_1's auc: 0.7351
# [2287]	training's binary_logloss: 0.329163	training's auc: 0.952643	valid_1's binary_logloss: 0.26271	valid_1's auc: 0.735099
# [2288]	training's binary_logloss: 0.329073	training's auc: 0.952687	valid_1's binary_logloss: 0.262582	valid_1's auc: 0.734985
# [2289]	training's binary_logloss: 0.329017	training's auc: 0.952716	valid_1's binary_logloss: 0.262526	valid_1's auc: 0.734971
# [2290]	training's binary_logloss: 0.328967	training's auc: 0.952733	valid_1's binary_logloss: 0.262527	valid_1's auc: 0.734973
# [2291]	training's binary_logloss: 0.32895	training's auc: 0.952737	valid_1's binary_logloss: 0.261733	valid_1's auc: 0.73475
# [2292]	training's binary_logloss: 0.328903	training's auc: 0.952755	valid_1's binary_logloss: 0.261526	valid_1's auc: 0.734791
# [2293]	training's binary_logloss: 0.328888	training's auc: 0.952759	valid_1's binary_logloss: 0.261524	valid_1's auc: 0.734785
# [2294]	training's binary_logloss: 0.328842	training's auc: 0.952782	valid_1's binary_logloss: 0.261481	valid_1's auc: 0.734763
# [2295]	training's binary_logloss: 0.328765	training's auc: 0.952815	valid_1's binary_logloss: 0.261457	valid_1's auc: 0.734735
# [2296]	training's binary_logloss: 0.328706	training's auc: 0.952838	valid_1's binary_logloss: 0.261426	valid_1's auc: 0.734731
# [2297]	training's binary_logloss: 0.328655	training's auc: 0.952861	valid_1's binary_logloss: 0.261419	valid_1's auc: 0.734711
# [2298]	training's binary_logloss: 0.328598	training's auc: 0.952892	valid_1's binary_logloss: 0.261417	valid_1's auc: 0.734711
# [2299]	training's binary_logloss: 0.328539	training's auc: 0.952918	valid_1's binary_logloss: 0.261316	valid_1's auc: 0.73471
# [2300]	training's binary_logloss: 0.328514	training's auc: 0.952925	valid_1's binary_logloss: 0.2613	valid_1's auc: 0.734657
# [2301]	training's binary_logloss: 0.328445	training's auc: 0.95297	valid_1's binary_logloss: 0.261263	valid_1's auc: 0.734671
# [2302]	training's binary_logloss: 0.328387	training's auc: 0.952992	valid_1's binary_logloss: 0.261241	valid_1's auc: 0.734668
# [2303]	training's binary_logloss: 0.328343	training's auc: 0.953008	valid_1's binary_logloss: 0.261221	valid_1's auc: 0.734685
# [2304]	training's binary_logloss: 0.328317	training's auc: 0.953012	valid_1's binary_logloss: 0.261192	valid_1's auc: 0.734649
# [2305]	training's binary_logloss: 0.328266	training's auc: 0.953032	valid_1's binary_logloss: 0.261142	valid_1's auc: 0.734629
# [2306]	training's binary_logloss: 0.328216	training's auc: 0.953049	valid_1's binary_logloss: 0.261122	valid_1's auc: 0.73456
# [2307]	training's binary_logloss: 0.328162	training's auc: 0.953074	valid_1's binary_logloss: 0.261096	valid_1's auc: 0.734565
# [2308]	training's binary_logloss: 0.32811	training's auc: 0.953101	valid_1's binary_logloss: 0.261053	valid_1's auc: 0.734558
# [2309]	training's binary_logloss: 0.328061	training's auc: 0.953119	valid_1's binary_logloss: 0.261049	valid_1's auc: 0.734494
# [2310]	training's binary_logloss: 0.327976	training's auc: 0.953148	valid_1's binary_logloss: 0.260993	valid_1's auc: 0.734481
# [2311]	training's binary_logloss: 0.327936	training's auc: 0.953163	valid_1's binary_logloss: 0.260965	valid_1's auc: 0.734477
# [2312]	training's binary_logloss: 0.327889	training's auc: 0.953178	valid_1's binary_logloss: 0.260924	valid_1's auc: 0.734441
# [2313]	training's binary_logloss: 0.327856	training's auc: 0.953186	valid_1's binary_logloss: 0.260934	valid_1's auc: 0.734472
# [2314]	training's binary_logloss: 0.327801	training's auc: 0.953218	valid_1's binary_logloss: 0.260911	valid_1's auc: 0.734468
# [2315]	training's binary_logloss: 0.327786	training's auc: 0.953222	valid_1's binary_logloss: 0.260906	valid_1's auc: 0.734443
# [2316]	training's binary_logloss: 0.327756	training's auc: 0.953232	valid_1's binary_logloss: 0.260876	valid_1's auc: 0.734491
# [2317]	training's binary_logloss: 0.327695	training's auc: 0.953251	valid_1's binary_logloss: 0.260877	valid_1's auc: 0.734477
# [2318]	training's binary_logloss: 0.327653	training's auc: 0.953267	valid_1's binary_logloss: 0.260849	valid_1's auc: 0.734476
# [2319]	training's binary_logloss: 0.327589	training's auc: 0.953313	valid_1's binary_logloss: 0.260796	valid_1's auc: 0.734461
# [2320]	training's binary_logloss: 0.327529	training's auc: 0.953339	valid_1's binary_logloss: 0.260775	valid_1's auc: 0.73444
# [2321]	training's binary_logloss: 0.327446	training's auc: 0.953385	valid_1's binary_logloss: 0.260703	valid_1's auc: 0.734432
# [2322]	training's binary_logloss: 0.327388	training's auc: 0.953404	valid_1's binary_logloss: 0.260675	valid_1's auc: 0.734477
# [2323]	training's binary_logloss: 0.327344	training's auc: 0.953417	valid_1's binary_logloss: 0.260681	valid_1's auc: 0.734477
# [2324]	training's binary_logloss: 0.327294	training's auc: 0.953435	valid_1's binary_logloss: 0.260588	valid_1's auc: 0.734459
# [2325]	training's binary_logloss: 0.327246	training's auc: 0.953458	valid_1's binary_logloss: 0.260559	valid_1's auc: 0.734459
# [2326]	training's binary_logloss: 0.327183	training's auc: 0.953491	valid_1's binary_logloss: 0.260523	valid_1's auc: 0.734424
# [2327]	training's binary_logloss: 0.327142	training's auc: 0.953504	valid_1's binary_logloss: 0.260501	valid_1's auc: 0.73439
# [2328]	training's binary_logloss: 0.327062	training's auc: 0.953554	valid_1's binary_logloss: 0.260476	valid_1's auc: 0.734378
# [2329]	training's binary_logloss: 0.327003	training's auc: 0.953572	valid_1's binary_logloss: 0.260473	valid_1's auc: 0.734368
# [2330]	training's binary_logloss: 0.326978	training's auc: 0.953579	valid_1's binary_logloss: 0.260449	valid_1's auc: 0.734377
# [2331]	training's binary_logloss: 0.326927	training's auc: 0.953598	valid_1's binary_logloss: 0.260415	valid_1's auc: 0.734366
# [2332]	training's binary_logloss: 0.326898	training's auc: 0.953606	valid_1's binary_logloss: 0.260376	valid_1's auc: 0.73431
# [2333]	training's binary_logloss: 0.326873	training's auc: 0.953615	valid_1's binary_logloss: 0.260377	valid_1's auc: 0.734316
# [2334]	training's binary_logloss: 0.326813	training's auc: 0.953642	valid_1's binary_logloss: 0.260342	valid_1's auc: 0.734291
# [2335]	training's binary_logloss: 0.326745	training's auc: 0.953668	valid_1's binary_logloss: 0.260272	valid_1's auc: 0.734276
# [2336]	training's binary_logloss: 0.32669	training's auc: 0.953704	valid_1's binary_logloss: 0.260244	valid_1's auc: 0.734246
# [2337]	training's binary_logloss: 0.326623	training's auc: 0.953737	valid_1's binary_logloss: 0.260208	valid_1's auc: 0.734284
# [2338]	training's binary_logloss: 0.326578	training's auc: 0.953759	valid_1's binary_logloss: 0.260176	valid_1's auc: 0.734276
# [2339]	training's binary_logloss: 0.326526	training's auc: 0.953775	valid_1's binary_logloss: 0.260113	valid_1's auc: 0.734279
# [2340]	training's binary_logloss: 0.32649	training's auc: 0.953791	valid_1's binary_logloss: 0.260112	valid_1's auc: 0.734276
# [2341]	training's binary_logloss: 0.326473	training's auc: 0.953795	valid_1's binary_logloss: 0.260104	valid_1's auc: 0.73428
# [2342]	training's binary_logloss: 0.326437	training's auc: 0.953811	valid_1's binary_logloss: 0.260086	valid_1's auc: 0.734273
# [2343]	training's binary_logloss: 0.326412	training's auc: 0.953818	valid_1's binary_logloss: 0.260067	valid_1's auc: 0.734268
# [2344]	training's binary_logloss: 0.326375	training's auc: 0.953831	valid_1's binary_logloss: 0.260039	valid_1's auc: 0.734275
# [2345]	training's binary_logloss: 0.326339	training's auc: 0.953842	valid_1's binary_logloss: 0.259988	valid_1's auc: 0.734241
# [2346]	training's binary_logloss: 0.326277	training's auc: 0.953866	valid_1's binary_logloss: 0.259913	valid_1's auc: 0.734287
# [2347]	training's binary_logloss: 0.326228	training's auc: 0.953883	valid_1's binary_logloss: 0.259875	valid_1's auc: 0.734292
# [2348]	training's binary_logloss: 0.326192	training's auc: 0.953896	valid_1's binary_logloss: 0.259857	valid_1's auc: 0.734267
# [2349]	training's binary_logloss: 0.326114	training's auc: 0.953922	valid_1's binary_logloss: 0.259792	valid_1's auc: 0.734236
# [2350]	training's binary_logloss: 0.32606	training's auc: 0.953948	valid_1's binary_logloss: 0.25976	valid_1's auc: 0.734205

# %%
get_learning_curves(model, metric="auc").show()
